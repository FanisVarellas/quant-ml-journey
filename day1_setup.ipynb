# %%
import yfinance as yf
data = yf.download("AAPL", period="5d")
print(data["Close"])
# Out:
# C:\Users\fanis\AppData\Local\Temp\ipykernel_25852\3660446433.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", period="5d")
# [*********************100%***********************]  1 of 1 completed
# Ticker            AAPL
# Date
# 2026-08-10  308.260010
# 2026-08-11  304.910004
# 2026-08-12  302.250000
# 2026-08-13  305.260010
# 2026-08-14  305.165009

# %%
print(data)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-08-10  308.260010  308.260010  304.609985  306.829987  44812500
# 2026-08-11  304.910004  309.970001  302.790009  307.750000  37476700
# 2026-08-12  302.250000  305.660004  300.570007  305.100006  41657800
# 2026-08-13  305.260010  306.000000  302.049988  304.209991  40316500
# 2026-08-14  305.165009  307.489990  304.660004  306.028015   8095888

# %%
data["Close"].plot(title="AAPL last 5 days")
# Out:
# <Axes: title={'center': 'AAPL last 5 days'}, xlabel='Date'>
