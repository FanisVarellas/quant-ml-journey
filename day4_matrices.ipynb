# %%
import numpy as np

# %%
A = np.array([[0, -1], [1, 0]])
B = np.array([[2, 0], [0, 1]])
print(A@B)
print(B@A)
# Out:
# [[ 0 -1]
#  [ 2  0]]
# [[ 0 -2]
#  [ 1  0]]

# %% [markdown]
# Multiplying two matrices creates one new matrix that represents applying both transformations, one after the other, in a single step.
